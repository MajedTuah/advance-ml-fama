# %% [markdown]
# # 📦 Topic 07 — API Serving & Containerization
#
# Welcome! In this notebook, we won't be training any models. Instead, we are focusing on **Deployment**.
#
# We will visualize the architecture of a machine learning API and how Docker layers work. For the actual coding activities, you will step out of this notebook and use the terminal to run the code in the `app/` folder!

# %% [markdown]
# ## 🏛️ 1. The API Architecture
#
# How does a mobile app actually talk to a Python Machine Learning model?
#
# Let's visualize the flow of data.

# %%
# TODO: Produce a readable plot or diagram plus a short interpretation of what it shows for API serving or container deployment and a visual analysis or architecture diagram. Pay attention to the original cell's intended step: Draw the components.## Before you prompt your AI, think through:#   - What should this cell produce, and how will you know that it worked?#   - Which assumptions, risks, or design choices matter for this result?## What to prompt your AI:#   "I am working in a Jupyter notebook section called 🏛️ 1. The API Architecture. Implement API serving or container deployment and a visual analysis or architecture diagram for this notebook section. Show me the reasoning first, then return runnable Python for this cell."## Context you MUST include:#   - You are working in the notebook section: 🏛️ 1. The API Architecture.#   - The notebook topic is \ud83d\udce6 Topic 07 \u2014 API Serving & Containerization\n",.#   - Use the variables, data, libraries, and file paths already established above.#   - Ask for an explanation of the reasoning and a runnable solution, not just a final answer.#   - Request code that fits this notebook's existing style and does not overwrite unrelated variables.#   - Mention the relevant variables or functions from this cell: ax, figsize, facecolor, color, ha, va, fontsize, fontweight.## Once you have code, check it against:#   - The output type, columns, shape, or metric expected by the next section.#   - A small sanity check that would reveal an empty, impossible, or leaked result.

# %% [markdown]
# ## 🍰 2. The Docker Layer Cake
#
# When you build a Docker Image, Docker executes your instructions step-by-step. Each step creates a **Layer**.
#
# If you change your python code, Docker doesn't want to re-install all your heavy libraries (like pandas and scikit-learn). It uses a cache! This is why the order of commands in a `Dockerfile` is so important.

# %%
# TODO: Produce a readable plot or diagram plus a short interpretation of what it shows for API serving or container deployment and a visual analysis or architecture diagram. Reconstruct the intended step from the section context and the variables already available.## Before you prompt your AI, think through:#   - What should this cell produce, and how will you know that it worked?#   - Which assumptions, risks, or design choices matter for this result?## What to prompt your AI:#   "I am working in a Jupyter notebook section called 🍰 2. The Docker Layer Cake. Implement API serving or container deployment and a visual analysis or architecture diagram for this notebook section. Show me the reasoning first, then return runnable Python for this cell."## Context you MUST include:#   - You are working in the notebook section: 🍰 2. The Docker Layer Cake.#   - The notebook topic is \ud83d\udce6 Topic 07 \u2014 API Serving & Containerization\n",.#   - Use the variables, data, libraries, and file paths already established above.#   - Ask for an explanation of the reasoning and a runnable solution, not just a final answer.#   - Request code that fits this notebook's existing style and does not overwrite unrelated variables.#   - Mention the relevant variables or functions from this cell: ax, figsize, layers, y_pos, facecolor, edgecolor, linewidth, color.## Once you have code, check it against:#   - The output type, columns, shape, or metric expected by the next section.#   - A small sanity check that would reveal an empty, impossible, or leaked result.

# %% [markdown]
# ## 🚀 3. Your Mission (In the Terminal)
#
# Now it is time to build it for real.
#
# 1. Open your code editor and look inside the `app/` folder.
# 2. Read `main.py` and `schemas.py`.
# 3. Open your terminal and run the API:
#    `uvicorn app.main:app --reload`
# 4. Open your browser and go to: `http://localhost:8000/docs`. You will see the beautiful Swagger UI. Try sending a prediction!
# 5. Stop the server (`Ctrl+C`).
# 6. Build the Docker image:
#    `docker build -t my-ml-api .`
# 7. Run the Docker container:
#    `docker run -p 8000:8000 my-ml-api`
#
# **Congratulations! You just put a machine learning model into production!**
